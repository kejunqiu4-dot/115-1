# %% [markdown]
# <a href="https://colab.research.google.com/github/kejunqiu4-dot/115-1/blob/main/411452052_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello\nHello")
# Out:
# Hello
# Hello

# %%
x=int(input(("請輸入目前金幣數量:")))
y=int(input("請輸入獲得金幣數量:"))
a=x+y
print(f"任務完成！你現在有{a}枚金幣")
# Out:
# 請輸入目前金幣數量:500
# 請輸入獲得金幣數量:250
# 任務完成！你現在有750枚金幣
